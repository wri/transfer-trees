# %% [markdown]
# # Area Assessments and Error Adjustments

# %%
import geopandas as gpd
import pandas as pd
import sys
import json
import numpy as np
import rasterio as rs
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling

sys.path.append('../../src/')
from evaluation import error_adjustments as err
from analyses import area_assessments as area

# %load_ext autoreload
# %autoreload 2

# %%
## background has higher recall, area is underrepresented
## monoculture has higher recall, area is underrepresented
## agroforestry has higher precision, area is overrepresented
## natural has higher precision, area is overrepresented

# %%
def reproject_to_meters(input_raster, output_raster, target_crs='EPSG:3857'):
    
    with rs.open(input_raster) as src:
        transform, width, height = calculate_default_transform(
            src.crs, target_crs, src.width, src.height, *src.bounds
        )
        kwargs = src.meta.copy()
        kwargs.update({
            'crs': target_crs,
            'transform': transform,
            'width': width,
            'height': height
        })

        with rs.open(output_raster, 'w', **kwargs) as dst:
            for i in range(1, src.count + 1):
                reproject(
                    source=rs.band(src, i),
                    destination=rs.band(dst, i),
                    src_transform=src.transform,
                    src_crs=src.crs,
                    dst_transform=transform,
                    dst_crs=target_crs,
                    resampling=Resampling.nearest
                )

# %%
prj_districts = gpd.read_file('../../data/epa_districts/Project_Districts.shp')
input_raster = '/Users/jessica.ertel/github/plantation_classifier/tmp/ghana/preds/mosaic/final_2024-10-29.tif'
repj_raster = '/Users/jessica.ertel/github/plantation_classifier/tmp/ghana/preds/mosaic/reprojected_2024-10-29.tif'

# reproject inputs from degrees to meters for area assessment calcs
dst_crs = 'EPSG:3857'
reproject_to_meters(input_raster, repj_raster, dst_crs)
prj_districts = prj_districts.to_crs(dst_crs)

with open("../../data/validation/ci_error_adjustment.json", "r") as f:
    error = json.load(f)

area_assess = area.calculate_adjusted_area(repj_raster, 
                                           prj_districts, 
                                           error, 
                                           '../../data/area_assessments/adj_area_assessment_081825.csv')

# %%
area_assess
# Out:
#                       District  Area (ha)  Background (ha)  Monoculture (ha)  \
# 0                 Adansi South    77457.0           5958.0            1072.0
# 1            Asante Akim South   117629.0           4611.0             655.0
# 2                  Assin North    73838.0           3360.0             730.0
# 3                Atwima Mponua   192078.0          11460.0            5126.0
# 4                   Bawku West   111788.0          92008.0               5.0
# 5                 Bosome Freho    57955.0           3538.0             743.0
# 6                 Builsa South   129292.0          99764.0               1.0
# 7         Daffiama Bussie Issa   151429.0         114227.0               0.0
# 8             Juaben Municipal    17479.0           1375.0             550.0
# 9          Kasena Nankana West    91116.0          68388.0              13.0
# 10    Kwahu Afram Plains North   239178.0         195824.0              75.0
# 11    Kwahu Afram Plains South   316224.0         182664.0              67.0
# 12                  Kwahu East    63654.0          23948.0             117.0
# 13                 Kwahu South    81204.0          33681.0             110.0
# 14                  Kwahu West    40876.0           3202.0             156.0
# 15           Mamprugu Moagduri   220569.0         158834.0              17.0
# 16            Sawla-Tuna-Kalba   437311.0         236909.0               2.0
# 3                Atwima Mponua
# 4                   Bawku West
# 5                 Bosome Freho
# 6                 Builsa South
# 7         Daffiama Bussie Issa
# 8             Juaben Municipal
# 9          Kasena Nankana West
# 10    Kwahu Afram Plains North
# 11    Kwahu Afram Plains South
# 12                  Kwahu East
# 13                 Kwahu South
# 14                  Kwahu West
# 15           Mamprugu Moagduri
# 16            Sawla-Tuna-Kalba
# 17  Sekyere Afram Plains North
# 18                   Sene West
# 19                Sissala East
# 20                Sissala West
# 21                     Talensi
# 22           Twifo Atti-Morkwa
# 23                     Wa East
# 24                  West Gonja
# 25     West Mamprusi Municipal

# %% [markdown]
# ## Create table for publication
#
# Cleans up and structures the results of the error adjusted area assessment table for input into the technical note.

# %%
area.area_assessment_table(input_f='adj_area_assessment_081825.csv',
                           output_f='adj_area_assessment_pubfigure_101025.csv',
                           include_summary_row=True)
# Out:
# Total area across all 26 districts (ha):
# Monoculture (ha)       13907
# Agroforestry (ha)    1562542
# Natural (ha)          897523
# dtype: int64
#      Zone                    District  Area (ha)  Monoculture (ha)  \
# 0   north     West Mamprusi Municipal   271590.0                10
# 1   north                     Wa East   446120.0                 0
# 2   north                     Talensi    87380.0                 0
# 3   north                  Bawku West   111790.0                 0
# 4   north                Sissala West   213860.0                10
# 5   north                Builsa South   129290.0                 0
# 6   north        Daffiama Bussie Issa   151430.0                 0
# 7   north                Sissala East   530900.0                10
# 8   north         Kasena Nankana West    91120.0                10
# 9   north                  West Gonja   487310.0                 0
# 10  north            Sawla-Tuna-Kalba   437310.0                 0
# 11  north           Mamprugu Moagduri   220570.0                20
# 12  south           Twifo Atti-Morkwa    97210.0              4220
# 13  south                   Sene West   334550.0                70
# 14  south  Sekyere Afram Plains North   360680.0               150
# 15  south                Adansi South    77460.0              1070
# 16  south                 Kwahu South    81200.0               110
# 17  south    Kwahu Afram Plains South   316220.0                70
# 18  south    Kwahu Afram Plains North   239180.0                80
# 19  south            Juaben Municipal    17480.0               550
# 20  south                Bosome Freho    57960.0               740
# 21  south               Atwima Mponua   192080.0              5130
# 22  south                 Assin North    73840.0               730
# 23  south           Asante Akim South   117630.0               660
# 24  south                  Kwahu West    40880.0               160
# 25  south                  Kwahu East    63650.0               120
# 26  NORTH                       TOTAL        NaN                70
# 27  SOUTH                       TOTAL        NaN             13840
#
#     Agroforestry (ha)  Natural (ha)
# 0               32540          2860
# 1               68180        106320
# 2               11100          2640
# 3               16630          2380
# 4               41450          8660
# 5               25810          3710
# 6               17880         19310
# 7              139900         42230
# 8               20160          2530
# 9              117770        145220
# 10              81810        118550
# 11              51560         10150
# 12              63140         26360
# 13              54660        135930
# 14             196600         95710
# 15              53780         16630
# 16              31160         16240
# 17              73350         60140
# 18              24300         18950
# 19              12400          3140
# 20              41720         11940
# 21             159430         16010
# 22              66770          2960
# 23              97540         14790
# 24              32930          4570
# 25              29990          9590
# 26             624780        464570
# 27             937760        432960

# %% [markdown]
# ### In-text statistics

# %%
with open("../../data/validation/ci_error_adjustment.json", "r") as f:
    error = json.load(f)

error
# Out:
# {'overall_accuracy': [0.6605820695807314, 0.027219000892060585],
#  'Monoculture': {'recall': [0.8, 0.2],
#   'precision': [0.2600760538896132, 0.12453933072577142],
#   'adj': 3.0760232940920904},
#  'No vegetation': {'recall': [0.899482320888658, 0.02734973167844318],
#   'precision': [0.7037827678338109, 0.03833655308379874],
#   'adj': 1.2780681227208721},
#  'Agroforestry': {'recall': [0.5287270764738249, 0.04639592178972898],
#   'precision': [0.6981959088700016, 0.04880965183435426],
#   'adj': 0.7572761022469262},
#  'Natural': {'recall': [0.4596836237383731, 0.06132923055588704],
#   'precision': [0.5795407200450948, 0.06722544910913414],
#   'adj': 0.793186065860229}}

# %%
368500+343410
# Out:
# 711910

# %% [markdown]
# ## Other // Not using

# %%
#calculate total area of raster (just for reference)
src = rs.open(repj_raster)
data = src.read(1)
valid_px = np.sum(data != src.nodata)
pixel_width = src.transform[0]  # X resolution
pixel_height = -src.transform[4]  # Y resolution
px_size = pixel_width * pixel_height
total_area_in_m2 = valid_px * (px_size)
total_area_in_ha = total_area_in_m2 / 10000

# sum all area assessments
# drops nodata column
district_total_area = df.iloc[:, :-2].sum().sum()

round(total_area_in_ha), round(district_total_area)
# Out:
# (5247876, 5247333)

# %%
df['ag_area'] = df.agroforestry + df.monoculture
df['nat_area'] = df.natural
df_pubfigure = df[['district', 'ag_area', 'nat_area']]
df_pubfigure
# Out:
#                       district    ag_area   nat_area
# 0                 Adansi South   54855.55   16628.07
# 1            Asante Akim South   98196.58   14791.46
# 2                  Assin North   67500.35    2964.08
# 3                Atwima Mponua  164552.60   16005.69
# 4                   Bawku West   16630.87    2381.25
# 5                 Bosome Freho   42459.31   11938.37
# 6                 Builsa South   25806.98    3711.35
# 7         Daffiama Bussie Issa   17875.03   19311.11
# 8             Juaben Municipal   12951.70    3137.66
# 9          Kasena Nankana West   20175.93    2528.68
# 10    Kwahu Afram Plains North   24373.48   18948.09
# 11    Kwahu Afram Plains South   73413.76   60141.82
# 12                  Kwahu East   30107.81    9594.09
# 13                 Kwahu South   31266.19   16239.89
# 14                  Kwahu West   33086.97    4568.67
# 15           Mamprugu Moagduri   51572.53   10150.94
# 16            Sawla-Tuna-Kalba   81811.75  118548.94
# 17  Sekyere Afram Plains North  196746.54   95706.79
# 18                   Sene West   54725.46  135931.87
# 19                Sissala East  139909.56   42230.16
# 20                Sissala West   41454.69    8661.84
# 21                     Talensi   11100.47    2635.45
# 22           Twifo Atti-Morkwa   67359.45   26359.50
# 23                     Wa East   68186.76  106324.96
# 24                  West Gonja  117774.76  145221.81
# 25     West Mamprusi Municipal   32552.46    2860.12
